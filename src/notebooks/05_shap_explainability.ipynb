# %% [markdown]
# # 05 — SHAP Explainability

# %%
import sys
sys.path.insert(0, "..")
import pandas as pd
from config import *
from explainability import compute_shap_values, plot_summary, plot_importance_bar, build_importance_comparison

# %%
# TODO: load best model (PRIMARY_POVERTY_THRESHOLD = "$3")
# TODO: compute SHAP values on test set
# TODO: plot_summary(), plot_bar(), plot_dependence() for each FEATURE_COL
